# %%
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import sklearn
import pandas as pd
import pint_pandas

# from DEXPI2sdRDM import DEXPI2sdRDM
from datetime import datetime
from sdRDM import DataModel
from modules import GCMDParser
from modules import GCEDParser
from modules import GstaticParser
from modules import MFMParser
from modules import Calculator
from pathlib import Path
from sdRDM import Generate_Python_API

# %%
model = DataModel.from_markdown('specifications/datamodel_b07_tc.md')

# %%
model.Datamodel.visualize_tree()
# Out:
# Datamodel
# ├── id
# ├── general_information
# │   └── GeneralInformation
# │       ├── id
# │       ├── title
# │       ├── description
# │       └── authors
# │           └── Author
# │               ├── id
# │               ├── name
# │               └── affiliation
# └── experiment
#     └── Experiment
#         ├── id
#         ├── plant_setup
#         │   └── PlantSetup
#         │       ├── id
#         │       ├── devices
#         │       │   └── Device
#         │       │       ├── id
#         │       │       ├── manufacturer
#         │       │       ├── device_type
#         │       │       ├── series
#         │       │       └── on_off
#         │       ├── tubing
#         │       │   └── Tubing
#         │       │       ├── id
#         │       │       ├── material
#         │       │       ├── inner_diameter
#         │       │       ├── outer_diameter
#         │       │       ├── length
#         │       │       └── insulation
#         │       │           └── Insulation
#         │       │               ├── id
#         │       │               ├── thickness
#         │       │               └── material
#         │       ├── input
#         │       │   └── Input
#         │       │       ├── id
#         │       │       └── component
#         │       │           └── Chemical
#         │       │               ├── id
#         │       │               ├── name
#         │       │               ├── formula
#         │       │               ├── pureness
#         │       │               ├── supplier
#         │       │               ├── stoichiometry
#         │       │               │   └── Stoichiometry
#         │       │               │       ├── id
#         │       │               │       ├── equivalents
#         │       │               │       ├── amount_of_substance
#         │       │               │       ├── mass
#         │       │               │       ├── volume
#         │       │               │       ├── density
#         │       │               │       ├── molar_mass
#         │       │               │       ├── mass_concentration
#         │       │               │       └── molar_concentration
#         │       │               ├── state_of_matter
#         │       │               └── role
#         │       └── output
#         │           └── Output
#         │               ├── id
#         │               └── component
#         │                   └── Chemical
#         │                       ├── id
#         │                       ├── name
#         │                       ├── formula
#         │                       ├── pureness
#         │                       ├── supplier
#         │                       ├── stoichiometry
#         │                       │   └── Stoichiometry
#         │                       │       ├── id
#         │                       │       ├── equivalents
#         │                       │       ├── amount_of_substance
#         │                       │       ├── mass
#         │                       │       ├── volume
#         │                       │       ├── density
#         │                       │       ├── molar_mass
#         │                       │       ├── mass_concentration
#         │                       │       └── molar_concentration
#         │                       ├── state_of_matter
#         │                       └── role
#         └── calculations
#             └── Calculations
#                 ├── id
#                 ├── calibrations
#                 │   └── Calibration
#                 │       ├── id
#                 │       ├── peak_area
#                 │       │   └── Data
#                 │       │       ├── id
#                 │       │       ├── values
#                 │       │       └── unit
#                 │       ├── concentration
#                 │       │   └── Data
#                 │       │       ├── id
#                 │       │       ├── values
#                 │       │       └── unit
#                 │       ├── slope
#                 │       │   └── Data
#                 │       │       ├── id
#                 │       │       ├── values
#                 │       │       └── unit
#                 │       ├── intercept
#                 │       │   └── Data
#                 │       │       ├── id
#                 │       │       ├── values
#                 │       │       └── unit
#                 │       └── coefficient_of_determination
#                 │           └── Data
#                 │               ├── id
#                 │               ├── values
#                 │               └── unit
#                 └── faraday_coefficients
#                     └── Data
#                         ├── id
#                         ├── values
#                         └── unit

# %%
a=model.Data(values=[1.5,2.5,3.5], unit=model.enums.Data.VOLFRAC)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/b07/lib/python3.10/site-packages/dotted_dict/__init__.py:34, in DottedDict.__getattr__(self, attr)
#      33 try:
# ---> 34     return self.__dict__[attr]
#      35 # Do this to match python default behavior
#
# KeyError: 'Data'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /mnt/c/Users/rscho/Documents/GitHub/datamodel_b07_tc/test_notebook.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/mnt/c/Users/rscho/Documents/GitHub/datamodel_b07_tc/test_notebook.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> a=model.Data(values=[1.5,2.5,3.5], unit=model.enums.Data.VOLFRAC)
#
# File ~/miniconda3/envs/b07/lib/python3.10/site-packages/dotted_dict/__init__.py:37, in DottedDict.__getattr__(self, attr)
#      35 # Do this to match python default behavior
#      36 except KeyError:
# ---> 37     raise AttributeError(attr)
#
# AttributeError: Data
