# %%
def gc_parser_selective_oxidation(data_path: Path):
    """
    Function that reads in a file from the gas chromotograph for the
    selective oxidation scenario. Important information that is extracted is the
    injection time, the retention times, as well as the peak areas.

    Args:
        data_path (Path): Path to measurement output file
    """

    column_names = [
        'Date',
        'Time',
        'Sample_Id',
        'Filename',
        'Method_name',
        'Username',
        'Vial',
        'Volume',
        'Autosampler_program',
        'MSA',
        'o-Xylol',
        'o-Toluylaldehyd',
        'o-Toluylsaeure',
        'PSA',
        'Phthalid',
        'unknown 13.64',
        'unknown 13.72',
    ]
    data_df = pd.read_csv(
        data_path,
        sep="\t",
        names=column_names,
        engine="python",
        encoding='cp1252',
        skiprows=3

    )
    datetime = pd.to_datetime(data_df.Date + ' ' + data_df.Time)
    data_df['datetime'] = datetime
    data_df = data_df.drop(columns=['Date', 'Time', 'Username', 'Volume', 'Autosampler_program',])
    cols = data_df.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    data_df = data_df[cols]
    return data_df

# %%
path = "/home/shambles/FAIRFlow/data/selective_oxidation/raw_data/GC/tl110511_µ-Reaktor_beschichtet_5vol%_350°C/PSA-Met-091214-Back_Signal.Area"
df = gc_parser_selective_oxidation(path)

df
# Out:
#               datetime                                             Sample_Id                                                                                                             Filename                                                             Method_name  Vial         MSA   o-Xylol o-Toluylaldehyd o-Toluylsaeure      PSA  Phthalid  unknown 13.64 unknown 13.72
# 0  2011-04-19 09:53:40  tl110419_5Vol%_350°C_A10K_VG21_µ-reaktor_beschichtet  c:\ezchrom elite\enterprise\projects\default\data\tl110419_5vol%_350°c_a10k_vg21_µ-reaktor_beschichtet_001-rep1.dat  C:\EZChrom Elite\Enterprise\Projects\Default\Method\PSA-Met-091214.met     1        1431  33851284            8191                  548117      8193           7823          1161
# ...
