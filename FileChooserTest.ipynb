# %%
# %reload_ext autoreload
# %autoreload 2
from ipyfilechooser import FileChooser
from pathlib import Path
root = Path.cwd()
# fc = FileChooser(root, show_only_dirs=True)
fc = FileChooser(root)
fc.title = 'Select directory'
display(fc)
# Out:
# FileChooser(path='/home/shambles/FAIRFlow', filename='', title='Select directory', show_hidden=False, select_d…

# %%
fc._dircontent

# %%
fc._pathlist

# %%
fc._filename.value
# Out:
# 'PSA-Met-091214-Back_Signal.Apex'

# %%
print(f'{type(fc.selected_path)}, {fc.selected_path})')
# Out:
# <class 'str'>, /home/shambles/FAIRFlow/data/selective_oxidation/raw_data/GC/tl110511_µ-Reaktor_beschichtet_5vol%_350°C)

# %%
fc._default_path

# %%
fc.selected_filename
# Out:
# 'PSA-Met-091214-Back_Signal.Apex'

# %%
fc._filename
